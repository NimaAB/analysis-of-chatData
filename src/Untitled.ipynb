# %%
#imports
import os
import numpy as np
import math
import json 
from datetime import datetime
import pandas as pd

# %%
with open('../data/message_1.json') as json_file:
    d = json.load(json_file)
'''
d = []

for el in data['messages']:
    if el['sender_name'] == "xx yy":
        intFormat = int(el['timestamp_ms'])
        #conv = datetime.datetime.fromtimestamp(intFormat)
        #date.append(conv.strftime('%Y-%m-%d %H:%M:%S'))
        d.append(intFormat)
dates = np.asarray(d)
dates
'''
data = pd.DataFrame.from_dict(d,orient='index')
data.reset_index(level=0,inplace=True)
data.head()
# Out:
#       index                                                  0  \
# 0  messages  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                    1  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16064...
#
#                                                    2  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16064...
#
#                                                    3  \
# 0  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                    4  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16064...
#
#                                                    5  \
# 0  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                    6  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16063...
#
#                                                    7  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16063...
#
#                                                    8  ...  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 16063...  ...
#
#                                                 1578  \
# 0  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                 1579  \
# 0  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                 1580  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15713...
#
#                                                 1581  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15713...
#
#                                                 1582  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15713...
#
#                                                 1583  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15710...
#
#                                                 1584  \
# 0  {'sender_name': 'Nima Abdollahi', 'timestamp_m...
#
#                                                 1585  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15710...
#
#                                                 1586  \
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15710...
#
#                                                 1587
# 0  {'sender_name': 'xx yy', 'timestamp_ms': 15710...
#
# [1 rows x 1589 columns]

# %%
#converting timestamps to day-month-year and hour:minute formar
#dates = map(lambda x: x.to_datetime(), dates)

#dates.astype('datetime64[s]').tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-8d9409186b38> in <module>
#       1 #converting timestamps to day-month-year and hour:minute formar
#       2 dates = map(lambda x: x.to_datetime(), dates)
# ----> 3 for i in dates:
#       4     print(i)
#       5 #dates.astype('datetime64[s]').tolist()
#
# <ipython-input-16-50754f2a6e62> in <lambda>(x)
#       1 #converting timestamps to day-month-year and hour:minute formar
# ----> 2 dates = map(lambda x: x.to_datetime(), dates)
#       3 #dates.astype('datetime64[s]').tolist()
#       4
#       5
#
# AttributeError: 'numpy.int64' object has no attribute 'to_datetime'

# %%
#then counting stamps which has equal day and month and year:
#then saving the counts in a vektor with a respective date:
# 
# ploting number of messages per day:
